# %% [markdown]
# <a href="https://colab.research.google.com/github/steveponce/2026-Fall-305/blob/main/cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cost Behavior Analysis
# ### Cost Accounting I - Riverbend Manufacturing
#
# We have 24 months of production and cost data.
# Our job is to work out how each cost behaves when the number of units produced changes.
#
# Cost driver (activity base): Units_Produced

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cost_behavior_data.csv')
# print("R and c:", df.shape)
# display(df.head())
# display(df.info())
display(df.describe())
# Out:
#        Units_Produced  Factory_Rent  Supervisor_Salary  Direct_Materials  \
# count       24.000000          24.0               24.0         24.000000
# mean      8295.833333       12000.0            18000.0      70514.583333
# std       2294.317966           0.0                0.0      19501.702708
# min       4600.000000       12000.0            18000.0      39100.000000
# 25%       6650.000000       12000.0            18000.0      56525.000000
# 50%       8200.000000       12000.0            18000.0      69700.000000
# 75%       9950.000000       12000.0            18000.0      84575.000000
# max      12600.000000       12000.0            18000.0     107100.000000
#
#        Direct_Labor     Utilities  Maintenance  Quality_Inspection
# count     24.000000     24.000000     24.00000           24.000000
# mean   49775.000000  13834.500000   8161.37500         9562.500000
# std    13765.907794   2842.109719   1715.83479         2755.675961
# ...
